# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
# !pip install xlrd
# !pip install openpyxl

# %%
exelfile = pd.ExcelFile('Time Table.xlsx')
exelfile

# %%
df1 = exelfile.parse('Sheet1')
df1
# Out:
#    Unnamed: 0    8:00-8:50                           8:50-9:40  \
# 0       DAY 1          NaN                                 NaN
# 1       DAY 2          NaN                                 NaN
# 2       DAY 3          NaN                                 NaN
# 3       DAY 4          NaN                                 NaN
# 4       DAY 5          NaN                                 NaN
# 5         NaN          NaN                                 NaN
# 6         NaN          NaN   Wireless and Mobile Communication
# 7         NaN          NaN       Database Security and Privacy
# 8         NaN          NaN  Water Pollution and its Management
# 9         NaN          NaN                                 NaN
# 10        NaN          NaN                                 NaN
# 11        NaN          NaN                                 NaN
# 12        NaN          NaN                                 NaN
# 13        NaN          NaN                                 NaN
# ...

# %%
df1.dropna()
df1
# Out:
#    Unnamed: 0    8:00-8:50                           8:50-9:40  \
# 0       DAY 1          NaN                                 NaN
# 1       DAY 2          NaN                                 NaN
# 2       DAY 3          NaN                                 NaN
# 3       DAY 4          NaN                                 NaN
# 4       DAY 5          NaN                                 NaN
# 5         NaN          NaN                                 NaN
# 6         NaN          NaN   Wireless and Mobile Communication
# 7         NaN          NaN       Database Security and Privacy
# 8         NaN          NaN  Water Pollution and its Management
# 9         NaN          NaN                                 NaN
# 10        NaN          NaN                                 NaN
# 11        NaN          NaN                                 NaN
# 12        NaN          NaN                                 NaN
# 13        NaN          NaN                                 NaN
# ...
