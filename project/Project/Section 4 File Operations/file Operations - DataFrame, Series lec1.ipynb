# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
df1 = pd.read_csv('data.csv')
df1
#first row is taken by default as a header
# Out:
#   First name   Last name  Age
# 0       Tinu    Elejogun   14
# 1     Javier      Zapata   28
# 2       Lily   McGarrett   18
# 3  Olatunkbo    Chijiaku   22
# 4   Adrienne    Anthoula   22
# 5     Axelia  Athanasios   22
# 6  Jon-Kabat        Zinn   22
# 7    Thabang       Mosoa   15
# 8      Rhian       Ellis   12

# %%
df2 = pd.read_csv('data.csv',header=None)
df2
# Out:
#             0           1    2
# 0  First name   Last name  Age
# 1        Tinu    Elejogun   14
# 2      Javier      Zapata   28
# 3        Lily   McGarrett   18
# 4   Olatunkbo    Chijiaku   22
# 5    Adrienne    Anthoula   22
# 6      Axelia  Athanasios   22
# 7   Jon-Kabat        Zinn   22
# 8     Thabang       Mosoa   15
# 9       Rhian       Ellis   12

# %%
#read_table()
#we can use custom seperator value

df3 = pd.read_table('data.csv', sep=',')
df3
# Out:
#   First name   Last name  Age
# 0       Tinu    Elejogun   14
# 1     Javier      Zapata   28
# 2       Lily   McGarrett   18
# 3  Olatunkbo    Chijiaku   22
# 4   Adrienne    Anthoula   22
# 5     Axelia  Athanasios   22
# 6  Jon-Kabat        Zinn   22
# 7    Thabang       Mosoa   15
# 8      Rhian       Ellis   12

# %%
#impoprt partial rows

df4 = pd.read_csv('data.csv',nrows=5)
df4
# Out:
#   First name  Last name  Age
# 0       Tinu   Elejogun   14
# 1     Javier     Zapata   28
# 2       Lily  McGarrett   18
# 3  Olatunkbo   Chijiaku   22
# 4   Adrienne   Anthoula   22

# %%
#dumping dataframe to csv

df3.to_csv('output.txt', sep = ' ')

# %%
#access specific column from csv

df3.to_csv('output01.txt',columns=['First name','Last name'])
